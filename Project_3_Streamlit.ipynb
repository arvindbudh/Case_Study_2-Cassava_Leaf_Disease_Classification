# %%
import nvidia_smi
# !nvidia-smi
# Out:
# Thu May 19 18:23:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    33W / 250W |   3245MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install albumentations==1.1.0

# %%
# !pip install opencv-python==4.5.4.60

# %%
# !pip install timm

# %%
#mouting google drive
from google.colab import drive
import os
drive.mount('/content/gdrive')
os.chdir("/content/gdrive/MyDrive/cassava/")
cwd = os.getcwd()
print(cwd)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/cassava

# %%
# !pip install -q pyngrok

# !pip install -q streamlit

# !pip install -q streamlit_ace

# %%
# !pip install ngrok

# %%
# !ngrok authtoken 24w3omcFSSpcHHsoJX7VgODLqKt_7nQ92C6NT9RUsSrzrVaH2
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !streamlit run case_study_3_deployment.py &>/dev/null&

# %%
#!killall ngrok

# %%
from pyngrok import ngrok
 
public_url = ngrok.connect('8501')
public_url
# Out:
# <NgrokTunnel: "http://cb0f-35-197-100-252.ngrok.io" -> "http://localhost:8501">

# %% [markdown]
# ## **Streamlit Screenshots**

# %% [markdown]
# ![ca1.png](data:image/png;base64,...)

# %% [markdown]
# ![ca2.png](data:image/png;base64,...)

# %% [markdown]
# ![ca3.png](data:image/png;base64,...)
